# %%
import fastbook
from fastai.vision.widgets import *
# !pip install ddgs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ddgs in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (9.14.4)
# Requirement already satisfied: click>=8.1.8 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from ddgs) (8.4.0)
# Requirement already satisfied: primp>=1.2.3 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from ddgs) (1.2.3)
# Requirement already satisfied: lxml>=4.9.4 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from ddgs) (6.1.1)
# Requirement already satisfied: httpx>=0.28.1 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.28.1)
# Requirement already satisfied: fake-useragent>=2.2.0 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from ddgs) (2.2.0)
# Requirement already satisfied: anyio in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.10.0)
# Requirement already satisfied: certifi in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.9)
# Requirement already satisfied: idna in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (3.10)
# Requirement already satisfied: h11>=0.16 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpcore==1.*->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (0.16.0)
# Requirement already satisfied: brotli in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.2.0)
# Requirement already satisfied: h2<5,>=3 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.3.0)
# Requirement already satisfied: socksio==1.* in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/jedidiahibironke/Library/Python/3.13/lib/python/site-packages (from anyio->httpx>=0.28.1->httpx[brotli,http2,socks]>=0.28.1->ddgs) (1.3.1)
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
learn_inf = load_learner(path/'export.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 learn_inf = load_learner(path/'export.pkl')
#
# NameError: name 'load_learner' is not defined

# %%
btn_upload = widgets.FileUpload()
btn_run = widgets.Button(description='Classify')
out_pl = widgets.Output()
lbl_pred = widgets.Label()

def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 btn_upload = widgets.FileUpload()
#       2 btn_run = widgets.Button(description='Classify')
#       3 out_pl = widgets.Output()
#
# NameError: name 'widgets' is not defined

# %%
display(VBox([widgets.Label('Select your console!'), 
              btn_upload, btn_run, out_pl, lbl_pred]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 display(VBox([widgets.Label('Select your console!'),
#       2               btn_upload, btn_run, out_pl, lbl_pred]))
#
# NameError: name 'VBox' is not defined
